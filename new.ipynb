# %%
import numpy as np

# %%
# for speech-to-text
import speech_recognition as sr
# for text-to-speech
# from gtts import gTTS
# for language model
import transformers
import os
import time
# for data
import os
import datetime
import numpy as np
# Building the AI
class ChatBot():
    def __init__(self, name):
        print("----- Starting up", name, "-----")
        self.name = name
    def inputText(self):
        self.text = input(" ?> ")
        print("Me  --> ", self.text)

    @staticmethod
    def text_to_speech(text):
        print("Dev --> ", text)
        # speaker = gTTS(text=text, lang="en", slow=False)
        # speaker.save("res.mp3")
        # statbuf = os.stat("res.mp3")
        # mbytes = statbuf.st_size / 1024
        # duration = mbytes / 200
        # os.system('start res.mp3')  #if you are using mac->afplay or else for windows->start
        # # os.system("close res.mp3")
        # time.sleep(int(50*duration))
        # os.remove("res.mp3")
    def wake_up(self, text):
        return True if self.name in text.lower() else False
    @staticmethod
    def action_time():
        return datetime.datetime.now().time().strftime('%H:%M')
# Running the AI
if __name__ == "__main__":
    ai = ChatBot(name="dev")
    nlp = transformers.pipeline("conversational", model="microsoft/DialoGPT-medium")
    os.environ["TOKENIZERS_PARALLELISM"] = "true"
    ex=True
    while ex:
        # ai.speech_to_text()
        ## wake up
        if ai.wake_up(ai.text) is True:
            res = "Hello I am Dave the AI, what can I do for you?"
        ## action time
        elif "time" in ai.text:
            res = ai.action_time()
        ## respond politely
        elif any(i in ai.text for i in ["thank","thanks"]):
            res = np.random.choice(["you're welcome!","anytime!","no problem!","cool!","I'm here if you need me!","mention not"])
        elif any(i in ai.text for i in ["exit","close"]):
            res = np.random.choice(["Tata","Have a good day","Bye","Goodbye","Hope to meet soon","peace out!"])
            ex=False
        ## conversation
        else:   
            if ai.text=="ERROR":
                res="Sorry, come again?"
            else:
                chat = nlp(transformers.Conversation(ai.text), pad_token_id=50256)
                res = str(chat)
                res = res[res.find("bot >> ")+6:].strip()
        ai.text_to_speech(res)
    print("----- Closing down Dev -----")

# %%
data
# Out:
# [{'First Name': 'Khairnar',
#   'Last Name': 'Technologies',
#   'Email': 'khairnartech@gmail.com',
#   'Accepts Email Marketing': 'yes',
#   'Company': nan,
#   'Address1': 'Khairnar Technologies Pvt Ltd',
#   'Address2': 'Level 5 Cohive Coworks Opp Vandevi Mandir Karvenagar Pune',
#   'City': 'Pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411052",
#   'Phone': 917028987266.0,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'Krish',
#   'Last Name': 'Khairnar',
#   'Email': 'krishikhairnar@gmail.com',
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Khairnar Technologies Pvt Ltd',
#   'Address2': 'Level 5 Cohive Coworks Opp Vandevi Mandir Karvenagar Pune',
#   'City': 'Pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411052",
#   'Phone': nan,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'Shubham',
#   'Last Name': 'Gupta',
#   'Email': 'shubham.gupta@kwiqreply.io',
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Viman Nagar',
#   'Address2': nan,
#   'City': 'Pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411014",
#   'Phone': nan,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'Shubham',
#   'Last Name': 'Gupta',
#   'Email': 'gshubham533@gmail.com',
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Sr. No. 45/4B house No. 236, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune',
#   'Address2': 'Near samrat sports club chandan nagar pune',
#   'City': 'pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411014",
#   'Phone': nan,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'Shubham',
#   'Last Name': 'Gupta',
#   'Email': nan,
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Sr. No. 45/4B house No. 236, Near samrat sp',
#   'Address2': 'Near samrat sports club chandan nagar pune',
#   'City': 'pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411014",
#   'Phone': 918208901203.0,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'fdfdfd',
#   'Last Name': 'Gupta',
#   'Email': nan,
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Sr. No. 45/4B house No. 236, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune',
#   'Address2': 'Near samrat sports club chandan nagar pune',
#   'City': 'pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411014",
#   'Phone': 917744994724.0,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'fdfdfd',
#   'Last Name': 'Gupta',
#   'Email': nan,
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Sr. No. 45/4B house No. 236, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune, Near samrat sports club chandan nagar pune',
#   'Address2': 'Near samrat sports club chandan nagar pune',
#   'City': 'pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411014",
#   'Phone': 917744994714.0,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'},
#  {'First Name': 'Shubham',
#   'Last Name': 'Gupta',
#   'Email': nan,
#   'Accepts Email Marketing': 'no',
#   'Company': nan,
#   'Address1': 'Sr. No. 45/4B house No. 236, Near samrat sports club chandan nagar pune',
#   'Address2': 'Near samrat sports club chandan nagar pune',
#   'City': 'pune',
#   'Province': 'Maharashtra',
#   'Province Code': 'MH',
#   'Country': 'India',
#   'Country Code': 'IN',
#   'Zip': "'411014",
#   'Phone': 918208901122.0,
#   'Accepts SMS Marketing': 'no',
#   'Total Spent': 0.0,
#   'Total Orders': 0,
#   'Tags': nan,
#   'Note': nan,
#   'Tax Exempt': 'no'}]

# %%
import pandas

def parseCSV(filepath):
    csv_file = pandas.read_csv(filepath)
    data = []

    for key in csv_file.columns:
        print(type(csv_file[key][0]), key)
    for x in range(len(csv_file)):
        thisrow = {}
        for key in csv_file.columns:
            thisrow[key] = csv_file[key][x]
        data.append(thisrow)
    return data

parseCSV("sample_data/products.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: 3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [3], line 16
#      13         data.append(thisrow)
#      14     return data
# ---> 16 parseCSV("sample_data/products.csv")
#
# Cell In [3], line 8, in parseCSV(filepath)
#       5 data = []
#       7 for key in csv_file.columns:
# ----> 8     print(type(csv_file[key][3]), key)
#       9 for x in range(len(csv_file)):
#      10     thisrow = {}
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/range.py:393, in RangeIndex.get_loc(self, key, method, tolerance)
#     391         return self._range.index(new_key)
#     392     except ValueError as err:
# --> 393         raise KeyError(key) from err
#     394 self._check_indexing_error(key)
#     395 raise KeyError(key)
#
# KeyError: 3
